# %% [markdown]
# # Clustering

# %%
# 라이브러리 불러오기
import pandas as pd
import seaborn as sns

# %%
# 데이터 불러오기
user_activity = pd.read_csv('C:/Users/User/Desktop/공부/Python/app_users.csv', index_col = [0])
user_activity.head()
# Out:
#    visit_per_month  use_time
# 0               14      22.8
# 1               32      13.6
# 2                8       3.1
# 3               13       5.7
# 4               19      20.8

# %%
# graph 설정
sns.set(style='darkgrid',rc={'figure.figsize':(16, 9)})

# 산점도 그리기
sns.scatterplot(x='visit_per_month', y='use_time', data=user_activity, s=100, palette='bright')
# Out:
# <AxesSubplot:xlabel='visit_per_month', ylabel='use_time'>

# %% [markdown]
# 산점도만으로는 정보를 얻기 힘들어 보인다.

# %% [markdown]
# ### Clustering 하기

# %%
from sklearn.cluster import KMeans

model = KMeans(n_clusters=3, random_state=123)
model.fit(user_activity)

# 클러스터 구분
user_activity['label'] = model.predict(user_activity)

# 클러스터별 속한 유저 수
user_activity.groupby('label').count()
# Out:
#        visit_per_month  use_time
# label
# 0                  228       228
# 1                  146       146
# 2                  126       126

# %%
sns.scatterplot(x='visit_per_month', y='use_time', data=user_activity, hue=user_activity['label'], s = 150, palette='bright')
# Out:
# <AxesSubplot:xlabel='visit_per_month', ylabel='use_time'>
